# %%
import xarray as xr
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
ddir = '/scratch/gpfs2/GEOCLIM/LRGROUP/MOM6-examples/ice_ocean_SIS2/OM4_05'

ds = xr.open_mfdataset(os.path.join(ddir,'*ocean_daily.nc'),chunks={'time':1})
print(ds)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-379b3c5d241b> in <module>()
#       1 ddir = '/scratch/gpfs2/GEOCLIM/LRGROUP/MOM6-examples/ice_ocean_SIS2/OM4_05'
#       2
# ----> 3 ds = xr.open_mfdataset(os.path.join(ddir,'*ocean_daily.nc'),chunks={'time':1})
#       4 print(ds)
#
# ~/code/miniconda/envs/standard/lib/python3.6/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, **kwargs)
#     498         paths = sorted(glob(paths))
#     499     if not paths:
# --> 500         raise IOError('no files to open')
#     501
#     502     if lock is None:
#
# OSError: no files to open

# %%
ds.thetao.isel(zl=0).mean('time').plot()
# Out:
# /home/jbusecke/code/miniconda/envs/standard/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
ddir = '/scratch/gpfs2/laurer/CM2.6/CM2.6_A_Control-1860_V03'

# %%
ds = xr.open_dataset(os.path.join(ddir,'0190-0199.ocean_minibling_field_temp.nc'),chunks={'time':1})

# %%
ds['temp'].isel(st_ocean=0).mean(['time']).plot()
# Out:
# /home/jbusecke/code/miniconda/envs/standard/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
ds['temp'].sel(xt_ocean=-180,method='nearest').sel(st_ocean=slice(0,1500)).mean(['time']).plot()
plt.gca().invert_yaxis()
# Out:
# /home/jbusecke/code/miniconda/envs/standard/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
ds['temp'].data
# Out:
# dask.array<open_dataset-4f55e8d8a08a12a2892418136d439996temp, shape=(12, 50, 2700, 3600), dtype=float64, chunksize=(1, 50, 2700, 3600)>
